# %%
import pandas as pd

# %%
# orders_qu.csv
url = "https://drive.google.com/file/d/1wxLuwU2bEdQjb2QkSNVY_sufkqb0zdlf/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orders = pd.read_csv(path)

# orderlines_qu.csv
url = "https://drive.google.com/file/d/1QCjywJchXxPch7IKOXhdsqHhO2AJLZwH/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orderlines = pd.read_csv(path)

# products_cl.csv
url = "https://drive.google.com/file/d/19-iDieCJdrnFv1W10OEXXkusJ4txCtb7/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products = pd.read_csv(path)

# brands.csv
url = "https://drive.google.com/file/d/1-0aOu3SxXmDwE4dUM4QFeiIXRGo_0u6L/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
brands = pd.read_csv(path)

# %%
orders_qu = orders.copy()
orderlines_qu = orderlines.copy()
products_cl = products.copy()
brands_df = brands.copy()

# %%
type(products['type'][0])
# Out:
# str

# %%
# columns ' 'Unnamed: 0' in orders and orderlines
orders_qu = orders_qu.drop('Unnamed: 0',axis=1)
orders_qu
# Out:
#        order_id         created_date  total_paid      state
# 0        241423  2017-11-06 13:10:02      136.15  Completed
# 1        242832  2017-12-31 17:40:03       15.76  Completed
# 2        243330  2017-02-16 10:59:38       84.98  Completed
# 3        245275  2017-06-28 11:35:37      149.00  Completed
# 4        245595  2017-01-21 12:52:47      112.97  Completed
# ...         ...                  ...         ...        ...
# 46143    527042  2018-03-14 11:47:50       18.98  Completed
# 46144    527070  2018-03-14 11:50:48       24.97  Completed
# 46145    527074  2018-03-14 11:51:42       24.97  Completed
# 46146    527096  2018-03-14 11:58:40       34.96  Completed
# 46147    527112  2018-03-14 12:03:52       14.98  Completed
#
# [46148 rows x 4 columns]

# %% [markdown]
# **Overall**

# %%
# also delte some unnecessary lines in orderlines
orderlines_qu = orderlines_qu.drop(['Unnamed: 0','product_id','Corrupted'],axis=1)
orderlines_qu
# Out:
#             id  id_order  product_quantity        sku  unit_price  \
# 0      1119116    299545                 1    OWC0100       47.49
# 1      1119119    299546                 1    IOT0014       18.99
# 2      1119120    295347                 1    APP0700       72.19
# 3      1119126    299549                 1    PAC0929      256.60
# 4      1119134    299556                 1  CRU0039-A       60.90
# ...        ...       ...               ...        ...         ...
# 61297  1649474    525664                 1    TUC0207       16.52
# 61298  1649512    527070                 2    APP0698        9.99
# 61299  1649522    527074                 2    APP0698        9.99
# 61300  1649565    527096                 3    APP0698        9.99
# 61301  1649593    527112                 1    APP0698        9.99
#
#                       date
# 0      2017-01-01 01:46:16
# 1      2017-01-01 01:50:34
# 2      2017-01-01 01:54:11
# 3      2017-01-01 02:07:42
# 4      2017-01-01 02:20:14
# ...

# %%
products_cl = products_cl.drop(['Unnamed: 0'],axis=1)
products_cl
# Out:
#            sku                                            name  \
# 0      RAI0007               Silver Rain Design mStand Support
# 1      APP0023               Apple Mac Keyboard Keypad Spanish
# 2      APP0025                Mighty Mouse Apple Mouse for Mac
# 3      APP0072   Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007     Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                             ...
# 10404  DJI0026  DJI Mavic Air Drone cuadricóptero Arctic White
# 10405  DJI0025    DJI Mavic Air Drone Black Onyx cuadricóptero
# 10406  LIN0013        Linksys Wi-Fi Velop system AC2200 1 unit
# 10407  LIN0014       Linksys Wi-Fi Velop system AC4400 2 units
# 10408  LIN0015       Linksys Wi-Fi Velop System AC6600 3 units
#
#                                                     desc      price  in_stock  \
# 0           Aluminum support compatible with all MacBook    59.9900         1
# ...

# %%
orders_qu.shape[0]
# Out:
# 46148

# %%
orderlines_qu.shape[0]
# Out:
# 61302

# %% [markdown]
# LMS
# *  What is the time period that the dataset covers?
# *  What is the overall revenue for that time?
# *   Are there seasonal patterns in the evolution of sales?
# *   What are the most sold products?
# *   What are the products that generate the most revenue?

# %%
merged_orders = orderlines_qu.merge(products_cl,
                                    on = 'sku',
                                    how = 'left')

# %%
merged_orders
# Out:
#             id  id_order  product_quantity        sku  unit_price  \
# 0      1119116    299545                 1    OWC0100       47.49
# 1      1119119    299546                 1    IOT0014       18.99
# 2      1119120    295347                 1    APP0700       72.19
# 3      1119126    299549                 1    PAC0929      256.60
# 4      1119134    299556                 1  CRU0039-A       60.90
# ...        ...       ...               ...        ...         ...
# 61297  1649474    525664                 1    TUC0207       16.52
# 61298  1649512    527070                 2    APP0698        9.99
# 61299  1649522    527074                 2    APP0698        9.99
# 61300  1649565    527096                 3    APP0698        9.99
# 61301  1649593    527112                 1    APP0698        9.99
#
#                       date                                               name  \
# 0      2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# ...

# %%
#the original set price minus the sold price meaning the diff_price is the discount
merged_orders['diff_price'] = merged_orders['price'] - merged_orders['unit_price']

#calculate the % of discount
merged_orders['%_discount'] = merged_orders['diff_price']/merged_orders['price']*100

# %% [markdown]
# **Time period:** that the dataset covered 1/1/17 to 14/3/18

# %%
orders_qu['created_date'].min()
# Out:
# '2017-01-01 01:51:47'

# %%
orders_qu['created_date'].max()
# Out:
# '2018-03-14 12:03:52'

# %%
orderlines_qu['date'].min()
# Out:
# '2017-01-01 01:46:16'

# %%
orderlines_qu['date'].max()
# Out:
# '2018-03-14 11:58:13'

# %% [markdown]
# **Overall Revenue**: during the time frame

# %%
orderlines_qu['unit_price_total'] = orderlines_qu['unit_price'] * orderlines_qu['product_quantity']

# %%
price_totals = (
  orderlines_qu
  .groupby('id_order')
  .agg({'unit_price_total':'sum'})
).reset_index() # makes sure we have a data frame and the id_order is accessible

# %%
orders_totals = orders_qu.merge(price_totals,
                                left_on = 'order_id',
                                right_on='id_order',
                                how='left')
orders_totals
# Out:
#        order_id         created_date  total_paid      state  id_order  \
# 0        241423  2017-11-06 13:10:02      136.15  Completed    241423
# 1        242832  2017-12-31 17:40:03       15.76  Completed    242832
# 2        243330  2017-02-16 10:59:38       84.98  Completed    243330
# 3        245275  2017-06-28 11:35:37      149.00  Completed    245275
# 4        245595  2017-01-21 12:52:47      112.97  Completed    245595
# ...         ...                  ...         ...        ...       ...
# 46143    527042  2018-03-14 11:47:50       18.98  Completed    527042
# 46144    527070  2018-03-14 11:50:48       24.97  Completed    527070
# 46145    527074  2018-03-14 11:51:42       24.97  Completed    527074
# 46146    527096  2018-03-14 11:58:40       34.96  Completed    527096
# 46147    527112  2018-03-14 12:03:52       14.98  Completed    527112
#
#        unit_price_total
# 0                129.16
# 1                 10.77
# 2                 77.99
# 3                149.00
# ...

# %%
orders_totals['difference'] = orders_totals['total_paid'] - orders_totals['unit_price_total']

# %%
orders_totals['unit_price_total'].sum()
# Out:
# 9131633.35

# %% [markdown]
# **Seasonal pattern in sales**

# %%
merged_orders['date'] = pd.to_datetime(merged_orders['date'])

# %%
(
    merged_orders
    .resample("M", on="date")
    .agg({'price': 'sum',
          'unit_price': 'sum'})
    .rename(columns={'price': 'revenue generated from original price',
                    'unit_price': 'revenue generated from discounted price'})
    .plot(figsize=(7, 5))
 );

# %% [markdown]
# First, to see the revenue behaviours from the real situation when the products are sold with discounted applied (orange line) compared to if the products were sold on the full original price (blue line). The difference between the 2 lines can represent the lost revenue from the discount. Althoug, the lost revenue is biggest between the 2 peaks in Nov/Dec time, the total revenue is also by far the highest.

# %%
(
    merged_orders
    .resample("M", on="date")
    .agg({'diff_price': 'sum'})
    .rename(columns={'diff_price': 'total discounts'})
    .plot(figsize=(7, 5))
 );

# %% [markdown]
# second, the zoom in of the lost revenue from the discount (the difference between the real sold price with discount & the originial based price). It can be seen there is a peak it lost revenue in Nov/Dec period. It it because of there are higher discounts given during the time?

# %%
(
    merged_orders
    .resample("M", on="date")
    .agg({'%_discount': 'mean'})
    .rename(columns={'%_discount': 'average discount'})
    .plot(figsize=(7, 5))
 );

# %% [markdown]
# It turns out that, the 'percentage' of given discount is not directly related to the high lost revenue during this period. Then if it is not because of higher percentage of the discount, the massive lower revenue could be explained by the higher number of products sold.

# %%
(
    merged_orders
    .resample("M", on="date")
    .agg({'product_quantity': 'sum'})
    .rename(columns={'product_quantity': 'total number of product sold'})
    .plot(figsize=(7, 5))
 );

# %% [markdown]
# Here the product quatity correlate with the high numbers of products sold, which explains the high lost revenue during the Nov/Dec period. However, the reason of it could still be investigated further. For example, Is if because, even though the % of discount is not different than other season, there are 'more number of prodcuts given discount'?

# %% [markdown]
# **Most sold products**

# %%
merged_orders.groupby(merged_orders['sku'])['product_quantity'].sum().sort_values(ascending=False)
# Out:
# sku
# APP1190      1020
# APP0698       838
# APP1922       572
# WDT0183       519
# APP0927       494
#              ...
# DLK0126         1
# DLK0132         1
# PAC2109         1
# PAC2108         1
# 8MO0001-A       1
# Name: product_quantity, Length: 5933, dtype: int64

# %%
products_cl.loc[products_cl['sku'] == 'APP1190']
# Out:
#           sku                              name  \
# 2622  APP1190  IPhone AppleCare Protection Plan
#
#                                       desc  price  in_stock  type
# 2622  Apple Care extended warranty iPhone.   70.0         1  1231

# %% [markdown]
# **Highest revenue product**

# %%
merged_orders.groupby(merged_orders['sku'])['unit_price'].sum().sort_values(ascending=False)
# Out:
# sku
# LGE0044      118325.12
# APP2446      101075.71
# APP1922       87263.92
# APP2477       83484.18
# APP1970       82914.84
#                ...
# IFX0017           2.99
# NTE0087-A         2.82
# PAR0037           1.99
# SEV0021           0.01
# SEV0018           0.01
# Name: unit_price, Length: 5933, dtype: float64

# %%
products_cl.loc[products_cl['sku'] == 'LGE0044']
# Out:
#           sku                                          name  \
# 5244  LGE0044  LG 27UD88-W Monitor 27 "UHD 4K USB 3.0 USB-C
#
#                                                    desc  price  in_stock  type
# 5244  99% Professional Monitor sRGB color calibrator...  599.0         1  1296
